# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('cosmetics.csv')

# %%
data
# Out:
#             Label                          Brand  \
# 0     Moisturizer                         LA MER
# 1     Moisturizer                          SK-II
# 2     Moisturizer                 DRUNK ELEPHANT
# 3     Moisturizer                         LA MER
# 4     Moisturizer                   IT COSMETICS
# ...           ...                            ...
# 1467  Sun protect                         KORRES
# 1468  Sun protect                KATE SOMERVILLE
# 1469  Sun protect                  VITA LIBERATA
# 1470  Sun protect  ST. TROPEZ TANNING ESSENTIALS
# 1471  Sun protect                     DERMAFLASH
#
#                                                    Name  Price  Rank  \
# 0                                       Crème de la Mer    175   4.1
# 1                              Facial Treatment Essence    179   4.1
# 2                            Protini™ Polypeptide Cream     68   4.4
# 3                           The Moisturizing Soft Cream    175   3.8
# ...

# %%
data.head()
# Out:
#          Label           Brand                                           Name  \
# 0  Moisturizer          LA MER                                Crème de la Mer
# 1  Moisturizer           SK-II                       Facial Treatment Essence
# 2  Moisturizer  DRUNK ELEPHANT                     Protini™ Polypeptide Cream
# 3  Moisturizer          LA MER                    The Moisturizing Soft Cream
# 4  Moisturizer    IT COSMETICS  Your Skin But Better™ CC+™ Cream with SPF 50+
#
#    Price  Rank                                        Ingredients  \
# 0    175   4.1  Algae (Seaweed) Extract, Mineral Oil, Petrolat...
# 1    179   4.1  Galactomyces Ferment Filtrate (Pitera), Butyle...
# 2     68   4.4  Water, Dicaprylyl Carbonate, Glycerin, Ceteary...
# 3    175   3.8  Algae (Seaweed) Extract, Cyclopentasiloxane, P...
# 4     38   4.1  Water, Snail Secretion Filtrate, Phenyl Trimet...
#
#    Combination  Dry  Normal  Oily  Sensitive
# 0            1    1       1     1          1
# ...

# %%
data.shape
# Out:
# (1472, 11)

# %%
data.dtypes
# Out:
# Label           object
# Brand           object
# Name            object
# Price            int64
# Rank           float64
# Ingredients     object
# Combination      int64
# Dry              int64
# Normal           int64
# Oily             int64
# Sensitive        int64
# dtype: object

# %%
data_s = data.sort_values(by = 'Price', ascending = True, na_position = 'first')

# %%
data_s
# Out:
#             Label               Brand  \
# 1063    Face Mask  SEPHORA COLLECTION
# 969     Face Mask  SEPHORA COLLECTION
# 976     Face Mask  SEPHORA COLLECTION
# 987     Face Mask  SEPHORA COLLECTION
# 498      Cleanser  SEPHORA COLLECTION
# ...           ...                 ...
# 665     Treatment           BIOEFFECT
# 790     Treatment            SHISEIDO
# 9     Moisturizer              LA MER
# 601     Treatment              LA MER
# 587     Treatment              LA MER
#
#                                                    Name  Price  Rank  \
# 1063                              Nose Mask - Pineapple      3   2.9
# 969                                          Nose Strip      3   2.8
# 976                                  Hydrating Lip Mask      3   3.0
# 987                                            Lip Mask      3   3.2
# 498                              Soft Touch Cotton Pads      4   4.6
# ...                                                 ...    ...   ...
# ...

# %%
price_data = data_s[['Price','Label','Brand','Name']]
price_data.head()
# Out:
#       Price      Label               Brand                    Name
# 1063      3  Face Mask  SEPHORA COLLECTION   Nose Mask - Pineapple
# 969       3  Face Mask  SEPHORA COLLECTION              Nose Strip
# 976       3  Face Mask  SEPHORA COLLECTION      Hydrating Lip Mask
# 987       3  Face Mask  SEPHORA COLLECTION                Lip Mask
# 498       4   Cleanser  SEPHORA COLLECTION  Soft Touch Cotton Pads

# %%
data_s.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1472 entries, 1063 to 587
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Label        1472 non-null   object
#  1   Brand        1472 non-null   object
#  2   Name         1472 non-null   object
#  3   Price        1472 non-null   int64
#  4   Rank         1472 non-null   float64
#  5   Ingredients  1472 non-null   object
#  6   Combination  1472 non-null   int64
#  7   Dry          1472 non-null   int64
#  8   Normal       1472 non-null   int64
#  9   Oily         1472 non-null   int64
#  10  Sensitive    1472 non-null   int64
# dtypes: float64(1), int64(6), object(4)
# memory usage: 138.0+ KB

# %%
data_s.describe()
# Out:
#              Price         Rank  Combination          Dry       Normal  \
# count  1472.000000  1472.000000   1472.00000  1472.000000  1472.000000
# mean     55.584239     4.153261      0.65625     0.614130     0.652174
# std      45.014429     0.633918      0.47512     0.486965     0.476442
# min       3.000000     0.000000      0.00000     0.000000     0.000000
# 25%      30.000000     4.000000      0.00000     0.000000     0.000000
# 50%      42.500000     4.300000      1.00000     1.000000     1.000000
# 75%      68.000000     4.500000      1.00000     1.000000     1.000000
# max     370.000000     5.000000      1.00000     1.000000     1.000000
#
#               Oily    Sensitive
# count  1472.000000  1472.000000
# mean      0.607337     0.513587
# std       0.488509     0.499985
# min       0.000000     0.000000
# 25%       0.000000     0.000000
# 50%       1.000000     1.000000
# 75%       1.000000     1.000000
# max       1.000000     1.000000

# %%
price_data.plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
data['Ingredients']
# Out:
# 0       Algae (Seaweed) Extract, Mineral Oil, Petrolat...
# 1       Galactomyces Ferment Filtrate (Pitera), Butyle...
# 2       Water, Dicaprylyl Carbonate, Glycerin, Ceteary...
# 3       Algae (Seaweed) Extract, Cyclopentasiloxane, P...
# 4       Water, Snail Secretion Filtrate, Phenyl Trimet...
#                               ...
# 1467    Water, Alcohol Denat., Potassium Cetyl Phospha...
# 1468    Water, Isododecane, Dimethicone, Butyloctyl Sa...
# 1469    Water, Dihydroxyacetone, Glycerin, Sclerocarya...
# 1470    Water, Dihydroxyacetone, Propylene Glycol, PPG...
# 1471                        Visit the DERMAFLASH boutique
# Name: Ingredients, Length: 1472, dtype: object

# %%
data.columns
# Out:
# Index(['Label', 'Brand', 'Name', 'Price', 'Rank', 'Ingredients', 'Combination',
#        'Dry', 'Normal', 'Oily', 'Sensitive'],
#       dtype='object')

# %%
data.sort_values(by = 'Ingredients')
# Out:
#            Label               Brand  \
# 263  Moisturizer           DR. JART+
# 656    Treatment            GUERLAIN
# 496     Cleanser                DIOR
# 39   Moisturizer           DR. JART+
# 799    Treatment  REN CLEAN SKINCARE
# ..           ...                 ...
# 844    Face Mask             ORIGINS
# 458     Cleanser             ORIGINS
# 449     Cleanser             ORIGINS
# 657    Treatment       HUM NUTRITION
# 811    Treatment               FRESH
#
#                                                   Name  Price  Rank  \
# 263                   Water Drop Hydrating Moisturizer     36   4.1
# 656                  Abeille Royale Daily Repair Serum    150   3.6
# 496        Hydra Life Micellar Water No Rinse Cleanser     42   4.4
# 39                          Premium Beauty Balm SPF 45     39   4.2
# 799        Flash Hydro-Boost Instant Plumping Emulsion     42   4.5
# ..                                                 ...    ...   ...
# ...

# %%
data[data['Price']<100]
# Out:
#             Label                          Brand  \
# 2     Moisturizer                 DRUNK ELEPHANT
# 4     Moisturizer                   IT COSMETICS
# 5     Moisturizer                         TATCHA
# 6     Moisturizer                 DRUNK ELEPHANT
# 7     Moisturizer                 DRUNK ELEPHANT
# ...           ...                            ...
# 1467  Sun protect                         KORRES
# 1468  Sun protect                KATE SOMERVILLE
# 1469  Sun protect                  VITA LIBERATA
# 1470  Sun protect  ST. TROPEZ TANNING ESSENTIALS
# 1471  Sun protect                     DERMAFLASH
#
#                                                    Name  Price  Rank  \
# 2                            Protini™ Polypeptide Cream     68   4.4
# 4         Your Skin But Better™ CC+™ Cream with SPF 50+     38   4.1
# 5                                       The Water Cream     68   4.2
# 6                             Lala Retro™ Whipped Cream     60   4.2
# ...

# %%
data[data['Ingredients'].isin(['Leaf'])]
# Out:
# Empty DataFrame
# Columns: [Label, Brand, Name, Price, Rank, Ingredients, Combination, Dry, Normal, Oily, Sensitive]
# Index: []

# %%
data[data['Price']>200]
# Out:
#             Label         Brand  \
# 9     Moisturizer        LA MER
# 19    Moisturizer         SK-II
# 29    Moisturizer         SK-II
# 52    Moisturizer        LA MER
# 85    Moisturizer         FRESH
# 116   Moisturizer         SK-II
# 147   Moisturizer         SK-II
# 162   Moisturizer        LA MER
# 170   Moisturizer      SHISEIDO
# 293   Moisturizer        LA MER
# 587     Treatment        LA MER
# 601     Treatment        LA MER
# 613     Treatment        LA MER
# 636     Treatment        LA MER
# 665     Treatment     BIOEFFECT
# 669     Treatment        LANCER
# 708     Treatment        LANCER
# 790     Treatment      SHISEIDO
# 811     Treatment         FRESH
# 818     Treatment         FRESH
# 840     Face Mask        LA MER
# 871     Face Mask        LA MER
# 1068    Face Mask        LANCER
# 1093    Eye cream        LA MER
# 1101    Eye cream        LA MER
# 1120    Eye cream        LA MER
# 1181    Eye cream  AMOREPACIFIC
# 1271    Eye cream      GUERLAIN
# ...

# %%
data.plot(kind='bar',colormap = 'RdYlGn_r',alpha=0.5)
# Out:
# <AxesSubplot:>
